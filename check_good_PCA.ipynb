# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('roberta_embeddings_english_abstractive.csv')

# %%
df
# Out:
#             0         1         2         3         4         5         6  \
# 0   -0.045318  0.106291 -0.003215 -0.067849  0.027385 -0.127473 -0.029526
# 1   -0.051724  0.116939  0.019695 -0.105494  0.033264 -0.070311 -0.006279
# 2   -0.010546  0.108884  0.001479 -0.138257  0.051355 -0.135540  0.008098
# 3   -0.054942  0.087816  0.019472 -0.118021  0.059199 -0.082324 -0.024870
# 4   -0.026756  0.077807 -0.000185 -0.094653  0.057685 -0.071129 -0.000685
# ..        ...       ...       ...       ...       ...       ...       ...
# 595 -0.052280  0.063353 -0.029092 -0.112168  0.026026 -0.086139 -0.025001
# 596 -0.040454  0.080203 -0.015394 -0.101792  0.036181 -0.041597  0.007757
# 597 -0.067318  0.111115 -0.009719 -0.082606  0.054640 -0.103232 -0.002115
# 598 -0.064715  0.088847 -0.013383 -0.087596  0.054902 -0.089861 -0.038170
# 599 -0.054698  0.137445  0.013111 -0.082863  0.036587 -0.051519 -0.023912
#
#             7         8         9  ...       759       760       761  \
# ...

# %%
X = df.iloc[:,:-1]

# %%
X
# Out:
#             0         1         2         3         4         5         6  \
# 0   -0.045318  0.106291 -0.003215 -0.067849  0.027385 -0.127473 -0.029526
# 1   -0.051724  0.116939  0.019695 -0.105494  0.033264 -0.070311 -0.006279
# 2   -0.010546  0.108884  0.001479 -0.138257  0.051355 -0.135540  0.008098
# 3   -0.054942  0.087816  0.019472 -0.118021  0.059199 -0.082324 -0.024870
# 4   -0.026756  0.077807 -0.000185 -0.094653  0.057685 -0.071129 -0.000685
# ..        ...       ...       ...       ...       ...       ...       ...
# 595 -0.052280  0.063353 -0.029092 -0.112168  0.026026 -0.086139 -0.025001
# 596 -0.040454  0.080203 -0.015394 -0.101792  0.036181 -0.041597  0.007757
# 597 -0.067318  0.111115 -0.009719 -0.082606  0.054640 -0.103232 -0.002115
# 598 -0.064715  0.088847 -0.013383 -0.087596  0.054902 -0.089861 -0.038170
# 599 -0.054698  0.137445  0.013111 -0.082863  0.036587 -0.051519 -0.023912
#
#             7         8         9  ...       758       759       760  \
# ...

# %%
Y = df.iloc[:,-1]

# %%
Y
# Out:
# 0      1
# 1      2
# 2      0
# 3      0
# 4      3
#       ..
# 595    3
# 596    2
# 597    2
# 598    3
# 599    3
# Name: Judgement Status, Length: 600, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_scaled = scaler.fit_transform(X)

# %%
X_scaled_df = pd.DataFrame(X_scaled)

# %%
X_scaled_df
# Out:
#           0         1         2         3         4         5         6    \
# 0   -0.018288  1.391186  0.452763  0.684150 -1.665507 -1.229391 -0.691764
# 1   -0.348751  2.018775  2.238798 -0.951163 -1.433708  0.722884  0.630040
# 2    1.775388  1.544018  0.818678 -2.374452 -0.720471 -1.504911  1.447436
# 3   -0.514716  0.302321  2.221418 -1.495378 -0.411228  0.312589 -0.427034
# 4    0.939238 -0.287573  0.688968 -0.480226 -0.470938  0.694935  0.948059
# ..        ...       ...       ...       ...       ...       ...       ...
# 595 -0.377419 -1.139441 -1.564636 -1.241115 -1.719061  0.182290 -0.434486
# 596  0.232616 -0.146321 -0.496674 -0.790355 -1.318730  1.703570  1.428094
# 597 -1.153128  1.675489 -0.054317  0.043118 -0.590978 -0.401475  0.866774
# 598 -1.018857  0.363093 -0.339919 -0.173686 -0.580651  0.055172 -1.183190
# 599 -0.502136  3.227316  1.725547  0.031951 -1.302696  1.364710 -0.372518
#
#           7         8         9    ...       758       759       760  \
# ...

# %%
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.linear_model import LogisticRegression

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X_scaled_df,Y,test_size=0.3,random_state=42)

# %%
for n_components in [50,100,200,300,400]:
    pca = PCA(n_components=n_components,random_state=42)
    X_train_reduced = pca.fit_transform(X_train)
    X_test_reduced = pca.transform(X_test)

    model = LogisticRegression(max_iter=5000,random_state=42)
    model.fit(X_train_reduced,Y_train)

    accuracy = model.score(X_test_reduced, Y_test)
    print(f"PCA components: {n_components}, Test Accuracy: {accuracy:.4f}")
# Out:
# PCA components: 50, Test Accuracy: 0.4111
# PCA components: 100, Test Accuracy: 0.4000
# PCA components: 200, Test Accuracy: 0.3667
# PCA components: 300, Test Accuracy: 0.3722
# PCA components: 400, Test Accuracy: 0.3944

# %%
from sklearn.feature_selection import VarianceThreshold

selector = VarianceThreshold(threshold=0.1)
X_train_selected = selector.fit_transform(X_train)
X_test_selected = selector.transform(X_test)

# Train a model
model = LogisticRegression(max_iter=5000, random_state=42)
model.fit(X_train_selected, Y_train)
accuracy = model.score(X_test_selected, Y_test)
print(f"Accuracy after feature selection: {accuracy:.4f}")
# Out:
# Accuracy after feature selection: 0.4056

# %%
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(random_state=42)
rfe = RFE(model, n_features_to_select=100)
X_train_selected = rfe.fit_transform(X_train, Y_train)
X_test_selected = rfe.transform(X_test)

# Train and evaluate
model.fit(X_train_selected, Y_train)
accuracy = model.score(X_test_selected, Y_test)
print(f"Accuracy after RFE: {accuracy:.4f}")
# Out:
# Accuracy after RFE: 0.3778

# %%
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier

model = LogisticRegression(max_iter=5000, random_state=42)
rfe = RFE(model, n_features_to_select=100)
X_train_selected = rfe.fit_transform(X_train, Y_train)
X_test_selected = rfe.transform(X_test)

# Train and evaluate
model.fit(X_train_selected, Y_train)
accuracy = model.score(X_test_selected, Y_test)
print(f"Accuracy after RFE: {accuracy:.4f}")
# Out:
# Accuracy after RFE: 0.3111

# %%
X_train
# Out:
#           0         1         2         3         4         5         6    \
# 108  1.485142 -1.844271  0.769218  1.621014  1.239797 -0.998972 -0.621846
# 272  0.921559 -1.838101 -0.853328 -0.328974 -0.296338 -0.609031 -0.635993
# 599 -0.502136  3.227316  1.725547  0.031951 -1.302696  1.364710 -0.372518
# 479 -0.469414 -0.797389 -1.687360  1.684547 -0.402875 -0.508364  0.158368
# 436 -0.248801  0.909116  0.104825 -0.237355  0.289171  0.580565  0.756810
# ..        ...       ...       ...       ...       ...       ...       ...
# 71  -0.978642 -1.042207  1.586136 -0.713316  1.024827  0.610227 -0.613610
# 106 -0.226278 -0.170585  0.035645  1.143867 -0.306252 -1.094703  0.475713
# 270  1.025705 -0.218530 -0.145913  0.019784  1.082833 -0.241029  0.048390
# 435  2.058806  0.942585  1.556872 -1.063577 -0.973636 -0.203272  2.620081
# 102 -0.783915  0.325675  0.518623 -0.958132  1.455591 -0.823366  2.084681
#
#           7         8         9    ...       758       759       760  \
# ...

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(penalty='l2', C=0.1, max_iter=5000, random_state=42)
model.fit(X_train, Y_train)

# Test accuracy
accuracy = model.score(X_test, Y_test)
print(f"Accuracy with L2 Regularization: {accuracy:.4f}")
# Out:
# Accuracy with L2 Regularization: 0.4056

# %%
for n_components in [50,100,200,300,400]:
    pca = PCA(n_components=n_components,random_state=42)
    X_train_reduced = pca.fit_transform(X_train)
    X_test_reduced = pca.transform(X_test)

    model = LogisticRegression(penalty='l2', C=0.1, max_iter=5000, random_state=42)
    model.fit(X_train_reduced,Y_train)

    accuracy = model.score(X_test_reduced, Y_test)
    print(f"PCA components: {n_components}, Test Accuracy: {accuracy:.4f}")
# Out:
# PCA components: 50, Test Accuracy: 0.4056
# PCA components: 100, Test Accuracy: 0.4056
# PCA components: 200, Test Accuracy: 0.3500
# PCA components: 300, Test Accuracy: 0.3722
# PCA components: 400, Test Accuracy: 0.4000

# %%
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

# %%
pca = PCA(n_components=400,random_state=42)

# %%
X
# Out:
#             0         1         2         3         4         5         6  \
# 0   -0.045318  0.106291 -0.003215 -0.067849  0.027385 -0.127473 -0.029526
# 1   -0.051724  0.116939  0.019695 -0.105494  0.033264 -0.070311 -0.006279
# 2   -0.010546  0.108884  0.001479 -0.138257  0.051355 -0.135540  0.008098
# 3   -0.054942  0.087816  0.019472 -0.118021  0.059199 -0.082324 -0.024870
# 4   -0.026756  0.077807 -0.000185 -0.094653  0.057685 -0.071129 -0.000685
# ..        ...       ...       ...       ...       ...       ...       ...
# 595 -0.052280  0.063353 -0.029092 -0.112168  0.026026 -0.086139 -0.025001
# 596 -0.040454  0.080203 -0.015394 -0.101792  0.036181 -0.041597  0.007757
# 597 -0.067318  0.111115 -0.009719 -0.082606  0.054640 -0.103232 -0.002115
# 598 -0.064715  0.088847 -0.013383 -0.087596  0.054902 -0.089861 -0.038170
# 599 -0.054698  0.137445  0.013111 -0.082863  0.036587 -0.051519 -0.023912
#
#             7         8         9  ...       758       759       760  \
# ...

# %%
X_reduced = pca.fit_transform(X)

# %%
X_reduced_df = pd.DataFrame(X_reduced)

# %%
X_reduced_df
# Out:
#           0         1         2         3         4         5         6    \
# 0    0.089323  0.251100  0.112058  0.064131 -0.136776  0.084511 -0.089436
# 1    0.298664  0.069992  0.021529 -0.018726  0.019512  0.057332 -0.073462
# 2    0.039490 -0.068089 -0.045467 -0.019295 -0.192849  0.084045 -0.104524
# 3    0.550370  0.210973  0.212728 -0.000346 -0.038487  0.120449 -0.028772
# 4   -0.128989 -0.124879  0.178070 -0.030919 -0.011790  0.132133 -0.134056
# ..        ...       ...       ...       ...       ...       ...       ...
# 595  0.378361 -0.014654  0.130074  0.135580 -0.247658 -0.075747  0.103285
# 596  0.576347  0.042378  0.215815  0.087873  0.063412 -0.059215  0.049936
# 597  0.269570 -0.026846  0.052297  0.091721 -0.047719 -0.141317 -0.084314
# 598  0.521524  0.149263  0.208518  0.224218 -0.226920  0.105146  0.253124
# 599  0.474676  0.085450 -0.060064  0.222538  0.081134 -0.195821 -0.039997
#
#           7         8         9    ...       390       391       392  \
# ...

# %%
X_train,X_test,Y_train,Y_test  = train_test_split(X_reduced_df,Y,test_size=0.2,random_state=42)

# %%
X_train
# Out:
#           0         1         2         3         4         5         6    \
# 145 -0.484338 -0.303535  0.342929  0.083130 -0.020296  0.004946  0.134673
# 9    0.108677  0.126117 -0.001788 -0.036962 -0.213025  0.078163 -0.120030
# 375  0.031669 -0.175580 -0.149583 -0.094422 -0.005915 -0.001240  0.062481
# 523  0.170168  0.051355 -0.110434 -0.078449  0.087406 -0.021500 -0.016570
# 188 -0.149981 -0.177447 -0.248277  0.077416  0.091923 -0.023775  0.066699
# ..        ...       ...       ...       ...       ...       ...       ...
# 71   0.049350  0.170892 -0.114446  0.000258  0.145118  0.178110  0.011043
# 106 -0.341587 -0.252754 -0.006362  0.081045 -0.011115 -0.028459 -0.002346
# 270 -0.424505 -0.036592  0.255932  0.058682 -0.053652  0.116477  0.011533
# 435  0.201622  0.039840  0.244947 -0.213921 -0.229682 -0.148169  0.033204
# 102  0.236417 -0.015162 -0.032897 -0.032157 -0.082999  0.108334 -0.041189
#
#           7         8         9    ...       390       391       392  \
# ...

# %%
xgb_model = XGBClassifier(reg_lambda = 0.1, random_state = 42,eval_metric ='logloss')

# %%
xgb_model.fit(X_train,Y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, objective='multi:softprob', ...)

# %%
xgb_pred = xgb_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
xgb_acc = accuracy_score(Y_test,xgb_pred)

# %%
print(f"XGBoost Accuracy with L2 Regularization: {xgb_acc:.4f}")
# Out:
# XGBoost Accuracy with L2 Regularization: 0.3083

# %%
xgb_model = XGBClassifier(reg_lambda = 0.1, random_state = 42,eval_metric ='mlogloss')

# %%
param_grid = {
    'alpha': np.logspace(-4, 4, 10),  # L1 regularization term
    'lambda': np.logspace(-4, 4, 10)  # L2 regularization term
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_search = GridSearchCV(estimator=xgb_model, param_grid=param_grid, cv=5, scoring='accuracy', verbose=2)
grid_search.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END ........................alpha=0.0001, lambda=0.0001; total time=   1.2s
# [CV] END ........................alpha=0.0001, lambda=0.0001; total time=   1.1s
# [CV] END ........................alpha=0.0001, lambda=0.0001; total time=   1.1s
# [CV] END ........................alpha=0.0001, lambda=0.0001; total time=   1.1s
# [CV] END ........................alpha=0.0001, lambda=0.0001; total time=   1.1s
# [CV] END ..........alpha=0.0001, lambda=0.000774263682681127; total time=   1.1s
# [CV] END ..........alpha=0.0001, lambda=0.000774263682681127; total time=   1.1s
# [CV] END ..........alpha=0.0001, lambda=0.000774263682681127; total time=   1.1s
# [CV] END ..........alpha=0.0001, lambda=0.000774263682681127; total time=   1.2s
# [CV] END ..........alpha=0.0001, lambda=0.000774263682681127; total time=   1.1s
# [CV] END ..........alpha=0.0001, lambda=0.005994842503189409; total time=   1.1s
# ...

# %%
best_alpha = grid_search.best_params_['alpha']
best_lambda = grid_search.best_params_['lambda']

# %%
print(f"Best L1 Regularization (alpha): {best_alpha}")
print(f"Best L2 Regularization (lambda): {best_lambda}")
# Out:
# Best L1 Regularization (alpha): 0.0001
# Best L2 Regularization (lambda): 0.0001

# %%
best_model = grid_search.best_estimator_

# %%
y_pred = best_model.predict(X_test)

# %%
print(f"Validation Accuracy: {accuracy_score(Y_test, y_pred)}")
# Out:
# Validation Accuracy: 0.31666666666666665

# %%
lgbm_model = LGBMClassifier(lambda_l2=1.0,  # L2 regularization term
                            random_state=42)
lgbm_model.fit(X_train, Y_train)
lgbm_pred = lgbm_model.predict(X_test)
lgbm_acc = accuracy_score(Y_test, lgbm_pred)
print(f"LightGBM Accuracy with L2 Regularization: {lgbm_acc:.4f}")
# Out:
# [LightGBM] [Warning] lambda_l2 is set=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [LightGBM] [Warning] lambda_l2 is set=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003781 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 64109
# [LightGBM] [Info] Number of data points in the train set: 480, number of used features: 400
# [LightGBM] [Info] Start training from score -1.473306
# [LightGBM] [Info] Start training from score -1.246532
# [LightGBM] [Info] Start training from score -1.361602
# [LightGBM] [Info] Start training from score -1.482438
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
catboost_model = CatBoostClassifier(l2_leaf_reg=3.0,  # L2 regularization term
                                     random_seed=42,
                                     verbose=0)
catboost_model.fit(X_train, Y_train)
catboost_pred = catboost_model.predict(X_test)
catboost_acc = accuracy_score(Y_test, catboost_pred)
print(f"CatBoost Accuracy with L2 Regularization: {catboost_acc:.4f}")
# Out:
# CatBoost Accuracy with L2 Regularization: 0.3333

# %%
from sklearn.ensemble import StackingClassifier

# %%
xgb_model = XGBClassifier(reg_lambda=1.0, random_state=42, eval_metric='logloss')
lgbm_model = LGBMClassifier(lambda_l2=1.0, random_state=42)
catboost_model = CatBoostClassifier(l2_leaf_reg=3.0, random_seed=42, verbose=0)

# Create a meta-model
meta_model = LogisticRegression()

# Use StackingClassifier for ensemble
stacking_model = StackingClassifier(
    estimators=[
        ('xgb', xgb_model),
        ('lgbm', lgbm_model),
        ('catboost', catboost_model)
    ],
    final_estimator=meta_model,
    cv=5  # Cross-validation for blending
)

# Train the stacking model
stacking_model.fit(X_train, Y_train)

# Make predictions
stacking_pred = stacking_model.predict(X_test)
stacking_acc = accuracy_score(Y_test, stacking_pred)
print(f"Stacking Model Accuracy: {stacking_acc:.4f}")
# Out:
# [LightGBM] [Warning] lambda_l2 is set=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [LightGBM] [Warning] lambda_l2 is set=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002710 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 64109
# [LightGBM] [Info] Number of data points in the train set: 480, number of used features: 400
# [LightGBM] [Info] Start training from score -1.473306
# [LightGBM] [Info] Start training from score -1.246532
# [LightGBM] [Info] Start training from score -1.361602
# [LightGBM] [Info] Start training from score -1.482438
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

# %%
base_models = [
    ('svc', SVC(probability=True, kernel='linear', random_state=42)),
    ('tree', DecisionTreeClassifier(max_depth=5, random_state=42))
]

# %%
meta_model = LogisticRegression(penalty='l2', C=0.1, random_state=42)

# %%
stacking_model = StackingClassifier(
    estimators=base_models,
    final_estimator=meta_model,
    cv=5  # Cross-validation for blending
)

# %%
stacking_model.fit(X_train, Y_train)
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('svc',
#                                 SVC(kernel='linear', probability=True,
#                                     random_state=42)),
#                                ('tree',
#                                 DecisionTreeClassifier(max_depth=5,
#                                                        random_state=42))],
#                    final_estimator=LogisticRegression(C=0.1, random_state=42))

# %%
stacking_pred = stacking_model.predict(X_test)
stacking_acc = accuracy_score(Y_test, stacking_pred)

print(f"Stacking Model Accuracy with L2-Regularized Meta-Model: {stacking_acc:.4f}")
# Out:
# Stacking Model Accuracy with L2-Regularized Meta-Model: 0.4000

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, ExtraTreesClassifier,AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
base_models = [
    ('lr', LogisticRegression(max_iter=5000, random_state=42)),              # Linear model
    ('rf', RandomForestClassifier(n_estimators=100, random_state=42)),       # Tree-based model
    ('svc', SVC(kernel='linear', probability=True, random_state=42)),        # SVM with linear kernel
    ('knn', KNeighborsClassifier(n_neighbors=5)),                            # K-Nearest Neighbors
    ('et', ExtraTreesClassifier(n_estimators=100, random_state=42)),         # Extra Trees Classifier
    ('xgb', XGBClassifier( eval_metric='logloss', random_state=42)),
    ('ada', AdaBoostClassifier(n_estimators=100, random_state=42)) 
]

# %%
meta_model = GradientBoostingClassifier(random_state=42)

# %%
stacking_model = StackingClassifier(estimators=base_models, final_estimator=meta_model, cv=5, n_jobs=-1)

# %%
stacking_model.fit(X_train, Y_train)
# Out:
# /opt/anaconda3/envs/may/lib/python3.12/site-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /opt/anaconda3/envs/may/lib/python3.12/site-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /opt/anaconda3/envs/may/lib/python3.12/site-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# ...

# %%
y_pred = stacking_model.predict(X_test)

# %%
accuracy = accuracy_score(Y_test, y_pred)
print(f"Stacking Model Test Accuracy: {accuracy}")
# Out:
# Stacking Model Test Accuracy: 0.4583333333333333

# %%
scoring = 'accuracy'

# %%
cv_ada_scores = cross_val_score(AdaBoostClassifier(n_estimators=100, random_state=42), X, Y, cv=5, scoring=scoring)
# Out:
# /opt/anaconda3/envs/may/lib/python3.12/site-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /opt/anaconda3/envs/may/lib/python3.12/site-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /opt/anaconda3/envs/may/lib/python3.12/site-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# ...

# %%
np.mean(cv_ada_scores)
# Out:
# 0.3433333333333333

# %%
np.std(cv_ada_scores)
# Out:
# 0.030459444804161788

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.pipeline import Pipeline
import numpy as np

# Define hyperparameter grids for each model
param_grids = {
    'lr': {
        'classifier__C': [0.1, 1, 10],           # Regularization strength
        'classifier__penalty': ['l1', 'l2'],    # Regularization type
        'classifier__solver': ['liblinear']     # Solver that supports l1 and l2
    },
    'rf': {
        'classifier__n_estimators': [50, 100, 200],
        'classifier__max_depth': [None, 10, 20, 30]
    },
    'svc': {
        'classifier__C': [0.1, 1, 10],          # Regularization strength
        'classifier__kernel': ['linear', 'rbf']
    },
    'knn': {
        'classifier__n_neighbors': [3, 5, 7],
        'classifier__weights': ['uniform', 'distance']
    },
    'et': {
        'classifier__n_estimators': [50, 100, 200],
        'classifier__max_depth': [None, 10, 20, 30]
    },
    'xgb': {
        'classifier__n_estimators': [50, 100, 200],
        'classifier__learning_rate': [0.01, 0.1, 0.2],
        'classifier__max_depth': [3, 5, 7]
    },
    'ada': {
        'classifier__n_estimators': [50, 100, 200],
        'classifier__learning_rate': [0.01, 0.1, 0.5]
    }
}

# Loop through each model and perform hyperparameter tuning
best_models = {}
for name, model in base_models:
    print(f"Tuning hyperparameters for: {name}")
    
    # Create a pipeline for standardization + model
    pipeline = Pipeline([
        ('scaler', StandardScaler()),
        ('classifier', model)
    ])
    
    # Choose GridSearchCV or RandomizedSearchCV
    search = RandomizedSearchCV(
        pipeline,
        param_distributions=param_grids[name],
        n_iter=20,  # Use GridSearchCV for exhaustive search, RandomizedSearchCV for faster results
        scoring='accuracy',
        cv=5,
        random_state=42,
        n_jobs=-1
    )
    
    # Fit the model
    search.fit(X_train, Y_train)
    
    # Store the best model
    best_models[name] = search.best_estimator_
    print(f"Best parameters for {name}: {search.best_params_}")
    print(f"Best cross-validated accuracy for {name}: {search.best_score_:.4f}\n")

# Evaluate the best models on the test set
for name, model in best_models.items():
    test_accuracy = model.score(X_test, Y_test)
    print(f"Test Accuracy for {name}: {test_accuracy:.4f}")
# Out:
# Tuning hyperparameters for: lr
# /opt/anaconda3/envs/may/lib/python3.12/site-packages/sklearn/model_selection/_search.py:320: UserWarning: The total space of parameters 6 is smaller than n_iter=20. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Best parameters for lr: {'classifier__solver': 'liblinear', 'classifier__penalty': 'l1', 'classifier__C': 1}
# Best cross-validated accuracy for lr: 0.3104
#
# Tuning hyperparameters for: rf
# /opt/anaconda3/envs/may/lib/python3.12/site-packages/sklearn/model_selection/_search.py:320: UserWarning: The total space of parameters 12 is smaller than n_iter=20. Running 12 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Best parameters for rf: {'classifier__n_estimators': 200, 'classifier__max_depth': 20}
# Best cross-validated accuracy for rf: 0.3208
#
# Tuning hyperparameters for: svc
# ...

# %%
base_models = [
    ('lr', LogisticRegression(solver='liblinear',penalty='l1',C=1,max_iter=5000, random_state=42)),              # Linear model
    ('rf', RandomForestClassifier(n_estimators=200,max_depth=20, random_state=42)),       # Tree-based model
    ('svc', SVC(kernel='rbf', C=1,probability=True, random_state=42)),        # SVM with linear kernel
    ('knn', KNeighborsClassifier(weights='distance',n_neighbors=7)),                            # K-Nearest Neighbors
    ('et', ExtraTreesClassifier(n_estimators=50,max_depth=10 ,random_state=42)),         # Extra Trees Classifier
    ('xgb', XGBClassifier(n_estimators = 50, max_depth = 5,learning_rate = 0.01 ,eval_metric='logloss', random_state=42)),
    ('ada', AdaBoostClassifier(n_estimators=50,learning_rate=0.1 ,random_state=42)) 
]

# %%
meta_model = GradientBoostingClassifier(random_state=42)

# %%
stacking_model = StackingClassifier(estimators=base_models, final_estimator=meta_model, cv=5, n_jobs=-1)

# %%
stacking_model.fit(X_train, Y_train)
# Out:
# /opt/anaconda3/envs/may/lib/python3.12/site-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /opt/anaconda3/envs/may/lib/python3.12/site-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /opt/anaconda3/envs/may/lib/python3.12/site-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# ...

# %%
y_pred = stacking_model.predict(X_test)

# %%
accuracy = accuracy_score(Y_test, y_pred)
print(f"Stacking Model Test Accuracy: {accuracy}")
# Out:
# Stacking Model Test Accuracy: 0.4166666666666667

# %% [markdown]
# ### Bayesian Optimization

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
import numpy as np

# Define the parameter grid for RandomizedSearchCV
param_grid = {
    'lr__C': np.logspace(-4, 4, 10),  # Logistic Regression regularization strength
    'rf__n_estimators': [100, 200, 300, 400],
    'rf__max_depth': [10, 20, 30, None],
    'svc__C': np.logspace(-4, 4, 10),  # SVM regularization strength
    'svc__kernel': ['linear', 'rbf'],
    'knn__n_neighbors': [3, 5, 7, 9],
    'gb__n_estimators': [100, 200, 300],
    'gb__learning_rate': [0.01, 0.1, 0.2],
    'xgb__n_estimators': [100, 200, 300],
    'xgb__learning_rate': [0.01, 0.1, 0.3],
    'ada__n_estimators': [50, 100, 200],
    'ada__learning_rate': [0.01, 0.1, 0.5]
}

# Set up the stacking classifier
base_models = [
    ('lr', LogisticRegression(max_iter=5000, random_state=42)),
    ('rf', RandomForestClassifier(random_state=42)),
    ('svc', SVC(probability=True, random_state=42)),
    ('knn', KNeighborsClassifier()),
    ('gb', GradientBoostingClassifier(random_state=42)),
    ('xgb', XGBClassifier(eval_metric='logloss', random_state=42)),
    ('ada', AdaBoostClassifier(random_state=42))
]

meta_model = LogisticRegression(max_iter=5000, random_state=42)

stacking_model = StackingClassifier(
    estimators=base_models,
    final_estimator=meta_model,
    cv=5
)

# Setup RandomizedSearchCV
random_search = RandomizedSearchCV(
    stacking_model,
    param_distributions=param_grid,
    n_iter=50,  # Increased number of iterations for better search
    cv=5,
    random_state=42,
    n_jobs=-1,
    verbose=2
)

# Train and evaluate the model with randomized search
random_search.fit(X_train, Y_train)

# Best parameters found by RandomizedSearchCV
print("Best parameters found: ", random_search.best_params_)

# Evaluate the best model
train_accuracy = random_search.score(X_train, Y_train)
test_accuracy = random_search.score(X_test, Y_test)

print(f"Train Accuracy: {train_accuracy:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# /opt/anaconda3/envs/may/lib/python3.12/site-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /opt/anaconda3/envs/may/lib/python3.12/site-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /opt/anaconda3/envs/may/lib/python3.12/site-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# ...

# %%
base_models = [
    ('lr', LogisticRegression(solver='liblinear',penalty='l1',max_iter=5000,C=21.54434690, random_state=42)),              # Linear model
    ('rf', RandomForestClassifier(n_estimators=200,max_depth=10, random_state=42)),       # Tree-based model
    ('svc', SVC(kernel='linear', C=166.8100,probability=True, random_state=42)),        # SVM with linear kernel
    ('knn', KNeighborsClassifier(weights='distance',n_neighbors=5)),                            # K-Nearest Neighbors
    ('et', ExtraTreesClassifier(n_estimators=50,max_depth=10 ,random_state=42)),         # Extra Trees Classifier
    ('xgb', XGBClassifier(n_estimators = 100, max_depth = 5,learning_rate = 0.01 ,eval_metric='logloss', random_state=42)),
    ('ada', AdaBoostClassifier(n_estimators=200,learning_rate=0.5 ,random_state=42)) 
]

# %%
meta_model = GradientBoostingClassifier(n_estimators=300,learning_rate=0.1,random_state=42)

# %%
stacking_model = StackingClassifier(estimators=base_models, final_estimator=meta_model, cv=5, n_jobs=-1)

# %%
stacking_model.fit(X_train,Y_train)
# Out:
# /opt/anaconda3/envs/may/lib/python3.12/site-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /opt/anaconda3/envs/may/lib/python3.12/site-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /opt/anaconda3/envs/may/lib/python3.12/site-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# ...

# %%
y_pred = stacking_model.predict(X_test)

# %%
y_pred
# Out:
# array([0, 2, 3, 1, 0, 0, 1, 3, 2, 2, 1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 1, 0,
#        2, 1, 2, 1, 1, 2, 1, 3, 2, 1, 1, 2, 2, 1, 1, 2, 0, 1, 3, 0, 2, 3,
#        1, 3, 3, 2, 3, 3, 2, 2, 1, 1, 2, 2, 3, 2, 3, 1, 1, 3, 2, 2, 0, 1,
#        1, 0, 1, 2, 0, 1, 0, 0, 2, 2, 1, 1, 0, 2, 3, 2, 2, 2, 2, 1, 3, 3,
#        1, 3, 0, 1, 0, 1, 0, 2, 3, 1, 0, 1, 1, 2, 1, 1, 1, 2, 3, 2, 1, 1,
#        2, 0, 1, 1, 0, 2, 2, 1, 2, 3])

# %%
print(accuracy_score(y_pred,Y_test))
# Out:
# 0.30833333333333335
